# %% [markdown]
# # Week 1- Graded Assignment 1
# Setting up the ML pipeline for IRIS Classifier in Vertex AI platform using GCS as demonstrated in the lecture (Hands-on: Introduction to Google Cloud, Vertex AI) in your GCP account.

# %% [markdown]
# ## Assignment Objective
#
# 1. Store Training Data in Google Storage Bucket
#
# 2. Fetch the data from Google Storage Bucket and Successfully execute the IRIS Machine Learning Training Pipeline
#
# 3. Store the Output artifacts (Models, logs, etc) in Google cloud storage bucket with folders organized by their training execution timestamp
#
# 4. Create a new script for inference and run the inference on eval set after fetching the models from GCS Output Artifacts Bucket
#
# 5. Run this Training and inference for 2 times resulting in two output artifact folders in Google cloud storage bucket
#
# 6. (Optional) Run this pipeline for two versions of data provided in github data folder

# %% [markdown]
# ## Initial steps

# %% [markdown]
# ### Install Vertex AI SDK for Python and other required packages

# %%
# Vertex SDK for Python
! pip3 install --upgrade --quiet  google-cloud-aiplatform
# Out:
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install --upgrade google-cloud-storage
# !pip install --upgrade google-cloud-storage google-cloud-aiplatform
# Out:
# Requirement already satisfied: google-cloud-storage in /opt/conda/lib/python3.10/site-packages (3.5.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.26.1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage) (2.41.1)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage) (2.28.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage) (2.7.2)
# Requirement already satisfied: requests<3.0.0,>=2.22.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage) (2.32.5)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage) (1.7.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (6.31.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (6.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.6.1)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: google-cloud-storage in /opt/conda/lib/python3.10/site-packages (3.5.0)
# Requirement already satisfied: google-cloud-aiplatform in /opt/conda/lib/python3.10/site-packages (1.126.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.26.1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage) (2.41.1)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage) (2.28.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage) (2.7.2)
# Requirement already satisfied: requests<3.0.0,>=2.22.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage) (2.32.5)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-storage) (1.7.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (6.31.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/conda/lib/python3.10/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (6.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (4.9.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in /opt/conda/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.6.1)
# Requirement already satisfied: packaging>=14.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (25.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (3.38.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.1.2)
# Requirement already satisfied: google-genai<2.0.0,>=1.37.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.42.0)
# Requirement already satisfied: pydantic<3 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.12.0)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (4.15.0)
# Requirement already satisfied: docstring_parser<1 in /opt/conda/lib/python3.10/site-packages (from google-cloud-aiplatform) (0.17.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.75.1)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /opt/conda/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.75.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from google-cloud-resource-manager<3.0.0,>=1.3.3->google-cloud-aiplatform) (0.14.2)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform) (4.11.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform) (0.28.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform) (15.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform) (1.3.1)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/conda/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.37.0->google-cloud-aiplatform) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in /opt/conda/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/conda/lib/python3.10/site-packages (from pydantic<3->google-cloud-aiplatform) (0.4.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (1.17.0)
# Requirement already satisfied: numpy>=1.21 in /opt/conda/lib/python3.10/site-packages (from shapely<3.0.0->google-cloud-aiplatform) (1.26.4)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Set Google Cloud project information

# %%
PROJECT_ID = "lively-nimbus-473407-m9"  # @param {type:"string"}
LOCATION = "us-central1"  # @param {type:"string"}

# %% [markdown]
# ### Create a Cloud Storage bucket
#
# Create a storage bucket to store intermediate artifacts such as datasets.

# %%
BUCKET_URI = f"gs://mlops-lively-nimbus-473407-m9"  # @param {type:"string"}

# %% [markdown]
# **If your bucket doesn't already exist** : Run the following cell to create your Cloud Storage bucket.

# %%
! gsutil mb -l {LOCATION} -p {PROJECT_ID} {BUCKET_URI}
# Out:
# Creating gs://mlops-lively-nimbus-473407-m9/...

# %% [markdown]
# ### Initialize Vertex AI SDK for Python

# %%
from google.cloud import aiplatform

aiplatform.init(project=PROJECT_ID, location=LOCATION, staging_bucket=BUCKET_URI)

# %% [markdown]
# ## 1. Store Training Data in Google Storage Bucket

# %% [markdown]
# ### Fetch data from git repository
# Data can not be saved directly to the cloud storage bucket from git repository, therefore we need an intermediate step i.e. to store the data locally

# %%
! git clone --branch week_1 https://github.com/IITMBSMLOps/ga_resources.git
# Out:
# Cloning into 'ga_resources'...
# remote: Enumerating objects: 37, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 37 (delta 8), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (37/37), 27.40 KiB | 6.85 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %% [markdown]
# ### Save data to bucket

# %%
! gsutil cp -r ga_resources/data/ {BUCKET_URI}/
# Out:
# Copying file://ga_resources/data/v1/data.csv [Content-Type=text/csv]...
# Copying file://ga_resources/data/raw/iris.csv [Content-Type=text/csv]...
# Copying file://ga_resources/data/v2/data.csv [Content-Type=text/csv]...
# / [3 files][  7.6 KiB/  7.6 KiB]
# Operation completed over 3 objects/7.6 KiB.

# %% [markdown]
# ## 2. IRIS Machine Learning Training Pipeline

# %% [markdown]
# ### Import important libraries

# %%
import os
import sys
import pandas as pd
import numpy as np
from pandas.plotting import parallel_coordinates
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn import metrics
from zoneinfo import ZoneInfo
from datetime import datetime

# %% [markdown]
# ### Fetch data from the bucket

# %%
! gsutil cp -r {BUCKET_URI}/data/ .
# Out:
# Copying gs://mlops-lively-nimbus-473407-m9/data/raw/iris.csv...
# Copying gs://mlops-lively-nimbus-473407-m9/data/v1/data.csv...
# Copying gs://mlops-lively-nimbus-473407-m9/data/v2/data.csv...
# / [3 files][  7.6 KiB/  7.6 KiB]
# Operation completed over 3 objects/7.6 KiB.

# %% [markdown]
# ### Import Dataset
#
# Remember to **update the path of data csv**

# %%
# data = pd.read_csv('data/raw/iris.csv')
# data = pd.read_csv('data/v1/data.csv')
data = pd.read_csv('data/v2/data.csv')
data.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Train Test Split

# %%
train, test = train_test_split(data, test_size = 0.4, stratify = data['species'], random_state = 42)
X_train = train[['sepal_length','sepal_width','petal_length','petal_width']]
y_train = train.species
X_test = test[['sepal_length','sepal_width','petal_length','petal_width']]
y_test = test.species

# %% [markdown]
# ### Eval Set

# %%
X_train, X_eval, y_train, y_eval = train_test_split(X_train, y_train, test_size = 0.2, stratify = y_train, random_state = 42)

# %% [markdown]
# ### Simple Decision Tree model
#
# Build a Decision Tree model on iris data

# %%
mod_dt = DecisionTreeClassifier(max_depth = 3, random_state = 1)
mod_dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=1)

# %% [markdown]
# ## 3. Store the Output artifacts
#
# Store the Output artifacts (Models, logs, etc) in Google cloud storage bucket with folders organized by their training execution timestamp

# %% [markdown]
# ### Path to your model artifacts
#
# `MODEL_ARTIFACT_DIR` - Folder directory path to your model artifacts within a Cloud Storage bucket

# %%
MODEL_ARTIFACT_DIR = f"iris_artifacts/{datetime.now(tz = ZoneInfo('Asia/Kolkata')).strftime('%Y%m%d_%H%M%S')}"
MODEL_ARTIFACT_DIR
# Out:
# 'iris_artifacts/20251106_112617'

# %% [markdown]
# ### Store the artifacts locally

# %%
import pickle
import joblib

! mkdir -p artifacts

joblib.dump(mod_dt, "artifacts/model.joblib")
# Out:
# ['artifacts/model.joblib']

# %% [markdown]
# ### Store the artifacts in Google Cloud Storage Bucket
#
# Before you can deploy your model for serving, Vertex AI needs access to the following files in Cloud Storage:
#
# - `model.joblib` (model artifact)
#
# - `preprocessor.pkl` (model artifact)
#
# Run the following commands to upload your files:

# %%
# Store output artifacts to google cloud storage bucket
! gsutil cp artifacts/model.joblib {BUCKET_URI}/{MODEL_ARTIFACT_DIR}/
# Out:
# Copying file://artifacts/model.joblib [Content-Type=application/octet-stream]...
# / [1 files][  2.2 KiB/  2.2 KiB]
# Operation completed over 1 objects/2.2 KiB.

# %% [markdown]
# ## 4. Create a new script for inference
#
# Run the inference on eval set after fetching the models from GCS Output Artifacts Bucket

# %% [markdown]
# ### Copy model from Bucket

# %%
! gsutil cp {BUCKET_URI}/{MODEL_ARTIFACT_DIR}/model.joblib .
# Out:
# Copying gs://mlops-lively-nimbus-473407-m9/iris_artifacts/20251106_112617/model.joblib...
# / [1 files][  2.2 KiB/  2.2 KiB]
# Operation completed over 1 objects/2.2 KiB.

# %% [markdown]
# ### Load model

# %%
model = joblib.load("./model.joblib")

# %% [markdown]
# ### Evaluating the Performance

# %% [markdown]
# #### Eval set

# %%
prediction=model.predict(X_eval)
print('The accuracy of the Decision Tree is',"{:.3f}".format(metrics.accuracy_score(prediction,y_eval)))
# Out:
# The accuracy of the Decision Tree is 1.000

# %% [markdown]
# #### Test set

# %%
prediction=model.predict(X_test)
print('The accuracy of the Decision Tree is',"{:.3f}".format(metrics.accuracy_score(prediction,y_test)))
# Out:
# The accuracy of the Decision Tree is 1.000

# %% [markdown]
# ## 5. Run this Training and inference for 2 times resulting in two output artifact folders in Google cloud storage bucket
#
# Run step 3 and 4 again

# %% [markdown]
# ## 6. (Optional) Run this pipeline for two versions of data provided in github data folder
#
# Change the data in step 2 and the further steps
